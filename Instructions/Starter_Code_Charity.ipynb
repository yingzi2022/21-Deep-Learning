# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("../Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df_new = application_df.drop(columns = ["EIN", "NAME"]) 
df_new.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
df_new.columns
# Out:
# Index(['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
#        'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS',
#        'ASK_AMT', 'IS_SUCCESSFUL'],
#       dtype='object')

# %%
# Determine the number of unique values in each column.
uniqueValues = df_new.nunique()
print(uniqueValues)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
applist2 = df_new['APPLICATION_TYPE'].value_counts()
applist2
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# Replace in dataframe
for app in application_types_to_replace:
    df_new['APPLICATION_TYPE'] = df_new['APPLICATION_TYPE'].replace(app,"Other")
#     df_new_app_type = df_new['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df_new['APPLICATION_TYPE'].value_counts()
# df_new_app_type.value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
df_new.nunique()
# Out:
# APPLICATION_TYPE             9
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
cls1 = list(df_new['CLASSIFICATION'].values.tolist())
cls1
# Out:
# ['C1000',
#  'C2000',
#  'C3000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C3000',
#  'C1200',
#  'C2000',
#  'C1200',
#  'C2700',
#  'C1000',
#  'C1200',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C3000',
#  'C1200',
#  'C7000',
#  'C3000',
#  'C1200',
#  'C3000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C2000',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C7200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1700',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C7000',
#  'C2000',
#  'C7000',
#  'C1200',
#  'C4000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C7000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C7000',
#  'C2000',
#  'C7100',
#  'C3000',
#  'C1200',
#  'C4000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1200',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2800',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1700',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C6000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2100',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C2000',
#  'C1200',
#  'C1700',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C1200',
#  'C1238',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C3000',
#  'C1000',
#  'C3000',
#  'C2100',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C2100',
#  'C2000',
#  'C7000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C7000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C5000',
#  'C1200',
#  'C7000',
#  'C1000',
#  'C1200',
#  'C7000',
#  'C1000',
#  'C1200',
#  'C7000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2100',
#  'C3000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C7120',
#  'C2000',
#  'C1000',
#  'C7100',
#  'C1200',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1200',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1200',
#  'C2000',
#  'C1200',
#  'C1200',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C3000',
#  'C1200',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1800',
#  'C1200',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C3000',
#  'C2000',
#  'C3000',
#  'C2000',
#  'C2000',
#  'C2000',
#  'C4000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C2000',
#  'C1200',
#  'C2100',
#  'C7000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C7000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C7000',
#  'C3000',
#  'C2100',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C7000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1200',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C3000',
#  'C1200',
#  'C1000',
#  'C3000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1700',
#  'C1200',
#  'C2700',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C7000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1200',
#  'C1200',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C7000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C4000',
#  'C4100',
#  'C7200',
#  'C1200',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C7000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C2700',
#  'C1200',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C3000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C4000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1400',
#  'C3000',
#  'C7000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C3000',
#  'C1200',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C2100',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C3000',
#  'C1000',
#  'C1200',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C3000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2800',
#  'C1000',
#  'C3000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C2000',
#  'C1200',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C2100',
#  'C2000',
#  'C3000',
#  'C2000',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1270',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C7000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C7000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C2100',
#  'C4000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2300',
#  'C1000',
#  'C2000',
#  'C7000',
#  'C2000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C3000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C3000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2100',
#  'C7000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C3000',
#  'C1200',
#  'C2100',
#  'C2100',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C2100',
#  'C2100',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C3000',
#  'C1000',
#  'C7000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1270',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C3000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C4000',
#  'C1000',
#  'C3000',
#  'C1270',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2100',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C3000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C3000',
#  'C2100',
#  'C1000',
#  'C2000',
#  'C3000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2800',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C7000',
#  'C2100',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C2100',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C1200',
#  'C1200',
#  'C2100',
#  'C2000',
#  'C7000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C5000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C7000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C5000',
#  'C1000',
#  'C1000',
#  'C2100',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2100',
#  'C1000',
#  'C8200',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C2100',
#  'C1200',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C3000',
#  'C2700',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C3000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C3000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1700',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C2700',
#  'C2000',
#  'C1000',
#  'C7000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1700',
#  'C1000',
#  'C2000',
#  'C7000',
#  'C1200',
#  'C2000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C7000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C2100',
#  'C2100',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C3000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1200',
#  'C1000',
#  'C1000',
#  'C1000',
#  'C2000',
#  'C1200',
#  'C7000',
#  'C1000',
#  'C2000',
#  'C1000',
#  'C2000',
#  'C2000',
#  'C2000',
#  'C2000',
#  'C2800',
#  'C1000',
#  ...]

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
cls2 = df_new['CLASSIFICATION'].unique()
cls2
# Out:
# array(['C1000', 'C2000', 'C3000', 'C1200', 'C2700', 'C7000', 'C7200',
#        'C1700', 'C4000', 'C7100', 'C2800', 'C6000', 'C2100', 'C1238',
#        'C5000', 'C7120', 'C1800', 'C4100', 'C1400', 'C1270', 'C2300',
#        'C8200', 'C1500', 'C7210', 'C1300', 'C1230', 'C1280', 'C1240',
#        'C2710', 'C2561', 'C1250', 'C8000', 'C1245', 'C1260', 'C1235',
#        'C1720', 'C1257', 'C4500', 'C2400', 'C8210', 'C1600', 'C1278',
#        'C1237', 'C4120', 'C2170', 'C1728', 'C1732', 'C2380', 'C1283',
#        'C1570', 'C2500', 'C1267', 'C3700', 'C1580', 'C2570', 'C1256',
#        'C1236', 'C1234', 'C1246', 'C2190', 'C4200', 'C0', 'C3200',
#        'C5200', 'C1370', 'C2600', 'C1248', 'C6100', 'C1820', 'C1900',
#        'C2150'], dtype=object)

# %%
cls3 = df_new['CLASSIFICATION'].value_counts()
cls3
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ['C2700', 'C7000', 'C7200',
       'C1700', 'C4000', 'C7100', 'C2800', 'C6000', 'C1238',
       'C5000', 'C7120', 'C1800', 'C4100', 'C1400', 'C1270', 'C2300',
       'C8200', 'C1500', 'C7210', 'C1300', 'C1230', 'C1280', 'C1240',
       'C2710', 'C2561', 'C1250', 'C8000', 'C1245', 'C1260', 'C1235',
       'C1720', 'C1257', 'C4500', 'C2400', 'C8210', 'C1600', 'C1278',
       'C1237', 'C4120', 'C2170', 'C1728', 'C1732', 'C2380', 'C1283',
       'C1570', 'C2500', 'C1267', 'C3700', 'C1580', 'C2570', 'C1256',
       'C1236', 'C1234', 'C1246', 'C2190', 'C4200', 'C0', 'C3200',
       'C5200', 'C1370', 'C2600', 'C1248', 'C6100', 'C1820', 'C1900',
       'C2150']

# Replace in dataframe
for cls in classifications_to_replace:
    df_new['CLASSIFICATION'] = df_new['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
# df_new_cls.value_counts()
df_new['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
df_new.nunique()
# Out:
# APPLICATION_TYPE             9
# AFFILIATION                  6
# CLASSIFICATION               6
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
df_new.columns
# Out:
# Index(['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
#        'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS',
#        'ASK_AMT', 'IS_SUCCESSFUL'],
#       dtype='object')

# %%
df_dummies = pd.get_dummies(df_new)
df_dummies
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = df_dummies.drop('IS_SUCCESSFUL', axis = 1).values
# X = df_dummies.drop('IS_SUCCESSFUL', axis = 1)(n_samples=1000,noise=0.08,random_state=78)
y = df_new['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled.shape[0]
# Out:
# 25724

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
# Instantiate KNN model and make predictions
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train_scaled, y_train)
y_pred = knn.predict(X_test_scaled)

# %%
# Assess the accuracy score
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7147521865889213

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
len(X_train[0])
# Out:
# 43

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

# Import our dependencies
import pandas as pd
import matplotlib as plt
import sklearn as skl
import tensorflow as tf

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=100, activation="relu", input_dim=43))

nn.add(tf.keras.layers.Dense(units=80, activation="sigmoid"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=50, activation="sigmoid"))

# Output layer

nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               4400
# _________________________________________________________________
# dense_1 (Dense)              (None, 80)                8080
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                4050
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 16,581
# Trainable params: 16,581
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model

nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model

fit = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5778 - accuracy: 0.7154: 0s - l
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5566 - accuracy: 0.7305
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5534 - accuracy: 0.7322: 0s - loss: 0.5567 - accuracy: 0. - ETA: 0s - loss:
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7320
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7338
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7335
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5491 - accuracy: 0.7328
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7345
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5477 - accuracy: 0.7338
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5473 - accuracy: 0.7343
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7357: 0s - loss: 0.5450 - accuracy:  - ETA: 0s - loss: 0.5452 - accuracy: 0.73 - ETA: 0s - loss: 0.5
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5464 - accuracy: 0.7335: 0s - loss: 0.5477 - accuracy: 0.
# Epoch 13/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7351
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5453 - accuracy: 0.7356
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5448 - accuracy: 0.7364
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5444 - accuracy: 0.7353
# Epoch 17/100
# 804/804 [==============================] - 1s 986us/step - loss: 0.5446 - accuracy: 0.7358
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5440 - accuracy: 0.7372
# Epoch 19/100
# 804/804 [==============================] - 1s 955us/step - loss: 0.5441 - accuracy: 0.7365
# Epoch 20/100
# 804/804 [==============================] - 1s 995us/step - loss: 0.5432 - accuracy: 0.7354
# Epoch 21/100
# 804/804 [==============================] - 1s 948us/step - loss: 0.5432 - accuracy: 0.7359
# Epoch 22/100
# 804/804 [==============================] - 1s 969us/step - loss: 0.5427 - accuracy: 0.7374
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7372
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7367
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7371
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5413 - accuracy: 0.7362
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7378
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7378
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5406 - accuracy: 0.7381
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5410 - accuracy: 0.7376
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7370
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7369
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5396 - accuracy: 0.7371
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5396 - accuracy: 0.7381
# Epoch 35/100
# 804/804 [==============================] - 1s 978us/step - loss: 0.5392 - accuracy: 0.7395
# Epoch 36/100
# 804/804 [==============================] - 1s 986us/step - loss: 0.5390 - accuracy: 0.7392
# Epoch 37/100
# 804/804 [==============================] - 1s 988us/step - loss: 0.5388 - accuracy: 0.7388
# Epoch 38/100
# 804/804 [==============================] - 1s 988us/step - loss: 0.5389 - accuracy: 0.7391
# Epoch 39/100
# 804/804 [==============================] - 1s 991us/step - loss: 0.5385 - accuracy: 0.7388
# Epoch 40/100
# 804/804 [==============================] - 1s 971us/step - loss: 0.5380 - accuracy: 0.7395
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7391
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7386
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7391
# Epoch 44/100
# 804/804 [==============================] - 1s 989us/step - loss: 0.5372 - accuracy: 0.7393
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5367 - accuracy: 0.7404
# Epoch 46/100
# 804/804 [==============================] - 1s 956us/step - loss: 0.5371 - accuracy: 0.7404
# Epoch 47/100
# 804/804 [==============================] - 1s 911us/step - loss: 0.5370 - accuracy: 0.7393
# Epoch 48/100
# 804/804 [==============================] - 1s 982us/step - loss: 0.5371 - accuracy: 0.7400
# Epoch 49/100
# 804/804 [==============================] - 1s 993us/step - loss: 0.5366 - accuracy: 0.7400
# Epoch 50/100
# 804/804 [==============================] - 1s 952us/step - loss: 0.5361 - accuracy: 0.7408
# Epoch 51/100
# 804/804 [==============================] - 1s 917us/step - loss: 0.5359 - accuracy: 0.7402
# Epoch 52/100
# 804/804 [==============================] - 1s 896us/step - loss: 0.5361 - accuracy: 0.7399
# Epoch 53/100
# 804/804 [==============================] - 1s 884us/step - loss: 0.5356 - accuracy: 0.7394
# Epoch 54/100
# 804/804 [==============================] - 1s 928us/step - loss: 0.5358 - accuracy: 0.7411
# Epoch 55/100
# 804/804 [==============================] - 1s 885us/step - loss: 0.5354 - accuracy: 0.7407
# Epoch 56/100
# 804/804 [==============================] - 1s 873us/step - loss: 0.5350 - accuracy: 0.7406
# Epoch 57/100
# 804/804 [==============================] - 1s 877us/step - loss: 0.5352 - accuracy: 0.7412
# Epoch 58/100
# 804/804 [==============================] - 1s 867us/step - loss: 0.5350 - accuracy: 0.7407
# Epoch 59/100
# 804/804 [==============================] - 1s 872us/step - loss: 0.5348 - accuracy: 0.7411
# Epoch 60/100
# 804/804 [==============================] - 1s 883us/step - loss: 0.5347 - accuracy: 0.7407
# Epoch 61/100
# 804/804 [==============================] - 1s 901us/step - loss: 0.5345 - accuracy: 0.7400
# Epoch 62/100
# 804/804 [==============================] - 1s 861us/step - loss: 0.5343 - accuracy: 0.7404
# Epoch 63/100
# 804/804 [==============================] - 1s 911us/step - loss: 0.5342 - accuracy: 0.7404
# Epoch 64/100
# 804/804 [==============================] - 1s 882us/step - loss: 0.5340 - accuracy: 0.7404
# Epoch 65/100
# 804/804 [==============================] - 1s 861us/step - loss: 0.5337 - accuracy: 0.7409
# Epoch 66/100
# 804/804 [==============================] - 1s 893us/step - loss: 0.5342 - accuracy: 0.7407
# Epoch 67/100
# 804/804 [==============================] - 1s 878us/step - loss: 0.5337 - accuracy: 0.7412
# Epoch 68/100
# 804/804 [==============================] - 1s 908us/step - loss: 0.5340 - accuracy: 0.7408
# Epoch 69/100
# 804/804 [==============================] - 1s 875us/step - loss: 0.5339 - accuracy: 0.7400
# Epoch 70/100
# 804/804 [==============================] - 1s 880us/step - loss: 0.5334 - accuracy: 0.7414
# Epoch 71/100
# 804/804 [==============================] - 1s 881us/step - loss: 0.5335 - accuracy: 0.7420
# Epoch 72/100
# 804/804 [==============================] - 1s 872us/step - loss: 0.5333 - accuracy: 0.7420
# Epoch 73/100
# 804/804 [==============================] - 1s 876us/step - loss: 0.5334 - accuracy: 0.7397
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7416
# Epoch 75/100
# 804/804 [==============================] - 1s 880us/step - loss: 0.5329 - accuracy: 0.7419
# Epoch 76/100
# 804/804 [==============================] - 1s 945us/step - loss: 0.5327 - accuracy: 0.7418
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.7418
# Epoch 78/100
# 804/804 [==============================] - 1s 991us/step - loss: 0.5325 - accuracy: 0.7423
# Epoch 79/100
# 804/804 [==============================] - 1s 956us/step - loss: 0.5327 - accuracy: 0.7415
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7415: 0s - loss: 0.5322 - accuracy: 0.74
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7428
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7415
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7419
# Epoch 84/100
# 804/804 [==============================] - 1s 874us/step - loss: 0.5322 - accuracy: 0.7421
# Epoch 85/100
# 804/804 [==============================] - 1s 985us/step - loss: 0.5319 - accuracy: 0.7419
# Epoch 86/100
# 804/804 [==============================] - 1s 990us/step - loss: 0.5320 - accuracy: 0.7420
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5323 - accuracy: 0.7417
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7416
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7418
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7417
# Epoch 91/100
# 804/804 [==============================] - 1s 986us/step - loss: 0.5323 - accuracy: 0.7415
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7422
# Epoch 93/100
# 804/804 [==============================] - 1s 992us/step - loss: 0.5313 - accuracy: 0.7421
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7419
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7424
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5311 - accuracy: 0.7430
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5311 - accuracy: 0.7420
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5311 - accuracy: 0.7428
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7415
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5308 - accuracy: 0.7418

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print()
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5719 - accuracy: 0.7248
#
# Loss: 0.5718564987182617, Accuracy: 0.724781334400177

# %%
# Export our model to HDF5 file
nn.save("charity_funding_predictor.HDF5")
# Out:
# WARNING:tensorflow:From C:\Users\yings\anaconda3\envs\PythonData38\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\yings\anaconda3\envs\PythonData38\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: charity_funding_predictor.HDF5\assets
